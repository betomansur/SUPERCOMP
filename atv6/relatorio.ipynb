# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Dados de exemplo
categorias = ['Entrada 1', 'Entrada 2', 'Entrada 3', 'Entrada 4']
valores = [0.00000158, 0.00000136, 0.00000180, 0.00000049]

# Criando o gráfico de barras
plt.bar(categorias, valores)

# Adicionando título e rótulos aos eixos
plt.title('Exemplo de Gráfico de Barras')
plt.xlabel('Categorias')
plt.ylabel('Valores')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Eles apresentam limitações severas em termos de tempo de execução e uso de memória, especialmente à medida que o tamanho do problema aumenta. Em muitos casos práticos, a escolha de métodos heurísticos ou aproximações pode ser necessária para obter soluções viáveis em tempo hábil e dentro dos limites de recursos disponíveis.
